# %%
import pandas as pd
import json

# %%
df = pd.read_csv("output.csv")

# %%
with open("train.jsonl", "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        item = {
            "prompt": row["prompt"],
            "response": row["response"]
        }
        f.write(json.dumps(item) + "\n")

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import HfApi

# Load environment variables from .env file
load_dotenv()

# Get the token
hf_token = os.getenv("HF_TOKEN")

# Upload using HfApi
api = HfApi(token=hf_token)
api.upload_folder(
    folder_path="/path/to/local/dataset",  # <-- update this to your actual path
    repo_id="mdot77/sp500p",
    repo_type="dataset",
)
# Out:
# Collecting huggingface_hubNote: you may need to restart the kernel to use updated packages.
#
#   Downloading huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\manov\anaconda3\lib\site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: colorama in c:\users\manov\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manov\anaconda3\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manov\anaconda3\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manov\anaconda3\lib\site-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manov\anaconda3\lib\site-packages (from requests->huggingface_hub) (2025.1.31)
# Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Installing collected packages: huggingface_hub
# Successfully installed huggingface_hub-0.33.0
