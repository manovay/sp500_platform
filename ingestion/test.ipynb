# %%
import pandas as pd

tickers = pd.read_csv('csvs/tickers.csv')['ticker'].astype(str).str.strip().unique()
allocs = pd.read_csv('csvs/allocations.csv')['ticker'].astype(str).str.strip().unique()

missing = set(allocs) - set(tickers)
print("Tickers in allocations.csv but missing from tickers.csv:", missing)
# Out:
# Tickers in allocations.csv but missing from tickers.csv: set()
